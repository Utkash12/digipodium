# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
print(mpl.__version__)
# Out:
# 3.7.2

# %%
xpoints=np.array([1,2,3,4])
ypoints=np.array([1,2,3,4])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])
plt.plot(xpoints,ypoints,'o-',color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
ypoints=np.array([2,4,6,4,2])
plt.plot(ypoints, color='green',marker='o',linestyle="dashed",linewidth=5,markersize=10)
plt.show()

# %%
ypoints=np.array([2,4,6,4,2])
plt.plot(ypoints,color="red",linewidth=2,marker="*",linestyle="dashed",markersize=14,markerfacecolor="blue")
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2, marker='o', linestyle='--', color='r', label='x1')
plt.show()

# %%
a=np.arange(10)
b=np.arange(10,20)
plt.plot(a,b,'r--',linewidth=2,label='a-b',alpha=0.5,marker='o',markersize=10,markerfacecolor='b',markeredgewidth=2)
plt.show()

# %%
a=np.random.randint(0,10,10)
b=np.random.randint(0,10,10)
plt.plot(a,b,'ro-')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
hindi=np.array([60,70,73,60,53,56])
maths=np.array([40,50,50,30,60,70])
english=np.array([90,70,50,60,80,45])
plt.xlabel('students',fontsize=10,fontweight='bold',color='red',fontstyle='italic',labelpad=10,rotation=25)
plt.ylabel('marks',fontsize=10,fontweight='bold',color='red',fontstyle='italic',labelpad=10,rotation=25)
plt.title('marks of students',fontsize=10,fontweight='bold',color='red',fontstyle='italic',pad=10,rotation=15)
plt.plot(hindi,'r--',marker='*')
plt.plot(english,'g--',marker='o')
plt.plot(maths,'b--',marker='^')
plt.show()

# %%
hindi=[60,70,73,60,53,56]
maths=[40,50,50,30,60,70]
english=[90,70,50,60,80,45]
plt.plot(hindi,'r--',label='hindi',marker='o',markersize=10)
plt.plot(english,'g--',label='english',marker='*',markersize=10)
plt.plot(maths,'b--',label='maths',marker='s',markersize=10)
plt.legend()
plt.show()

# %%
temp=np.array([40,45,50,43,30,55,41,60,37])
plt.plot(temp,'r--*',linewidth=2,markersize=12,markerfacecolor='b',markeredgecolor='g',markeredgewidth=2)
plt.grid(axis='y',color='black',linestyle='--',linewidth=2)
plt.xlabel('Day',fontsize=15)
plt.ylabel('Temperature',fontsize=15)
plt.title('Temperature variation',fontsize=20)
plt.show()

# %%
people=np.array([20000,10000,30000,15000,35000,10000])
year=np.arange(2016,2028,2)
plt.plot(year,people,'r*--')
plt.xlabel('year')
plt.ylabel('people')
plt.grid()
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1,1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1,2)
plt.plot(x,y)

plt.show()

# %%
x=np.arange(-5,5,0.2)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
fig,axs =plt.subplots(nrows=3,ncols=1,figsize=(5,10))
axs[0].plot(x,y1,'r--')
axs[1].plot(x,y2,'b--')
axs[2].plot(x,y3,'g--')
axs[0].set_title('sin(x)')
axs[1].set_title('cos(x)')
axs[2].set_title('tan(x)')
plt.show()

# %%
fig, a=plt.subplots(figsize=(12, 5))
x=[1, 2, 3, 4, 5]
y=[3,4,4,5,3]
a.plot(x, y,'o-')

# %%
# plt -> implicit figure and axes creation
x=np.linspace(-10,10,25)
plt.plot(x,x,'-',label='one')
plt.plot(x,x**2,'--',label='two')
plt.plot(x,x**3,'o',label='three')
plt.plot(x,x**4,'*',label='four')
plt.xlabel('my x label')
plt.ylabel('my y label')
plt.legend()
plt.title('simple plot with implicit graph settings')
plt.savefig('Plot1.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
hindi=np.array([60,70,40,50,70,55,60])
english=np.array([90,60,70,80,50,70,60])
maths=np.array([60,70,80,50,40,80,70])
plt.plot(hindi,'b^-', label='hindi')
plt.plot(english, 'g*-', label='english')
plt.plot(maths, 'ro-', label='maths')
plt.legend()
plt.title('marks of students')
plt.xlabel('students')
plt.ylabel('marks')
plt.grid()
plt.show()

# %%
hindi=np.array([60,70,40,50,70,55,60])
english=np.array([90,60,70,80,50,70,60])
maths=np.array([60,70,80,50,40,80,70])
physics=np.array([60,50,70,80,55,75])
plt.subplot(2,2,1)
plt.plot(hindi,'b^-', label='hindi')
plt.grid()
plt.legend()
plt.subplot(2,2,2)
plt.plot(english, 'g*-', label='english')
plt.legend()
plt.grid()
plt.subplot(2,2,3)
plt.legend()
plt.plot(maths, 'ro-', label='maths')
plt.grid()
plt.legend()
plt.subplot(2,2,4)
plt.plot(physics, 'y*-', label='physics')
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hindi=np.array([50,60,40,70,80,50])
english=np.array([70,80,55,60,70,90])
maths=np.array([60,80,50,85,60,75])
physics=np.array([60,70,40,45,90,65])



plt.subplot(2,2,1)
plt.title('hindi')
plt.grid()
plt.plot(hindi,'r-o', label='hindi')
plt.legend()



plt.subplot(2,2,2)
plt.grid()
plt.title('english')
plt.plot(english, 'g-*',label='english')
plt.legend()






plt.subplot(2,2,3)
plt.grid()
plt.title('maths')
plt.plot(maths, 'b-^',label='maths')
plt.legend()


plt.subplot(2,2,4)
plt.grid()
plt.title('physics')
plt.plot(physics, 'y-s',label='physics')



plt.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize=(7, 4))
x=[1, 2, 3, 4, 5]
y=[3,4,4,5,3]
ax.plot(x, y,'o-')

# %%
fig, axs =plt.subplots(nrows=1,ncols=2,figsize=(8,2))

# %%
x=np.arange(-5,5,0.2)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
fig,axs =plt.subplots(1,3,figsize=(15,3))
axs[0].plot(x,y1,'r--')
axs[1].plot(x,y2,'b--')
axs[2].plot(x,y3,'g--')
axs[0].set_title('sin(x)')
axs[1].set_title('cos(x)')
axs[2].set_title('tan(x)')
plt.show()

# %%
x=np.arange(40,100,10)
hindi=np.array([50,60,40,70,80,50])
english=np.array([70,80,55,60,70,90])
maths=np.array([60,80,50,85,60,75])
physics=np.array([60,70,40,45,90,65])

fig, xs=plt.subplots(2,2,figsize=(6,6))
xs[0].plot(hindi,'ro-')
xs[1].plot(english,'bo-')
xs[2].plot(maths,'go-')
xs[3].plot(physics,'yo-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 8
#       5 physics=np.array([60,70,40,45,90,65])
#       7 fig, xs=plt.subplots(2,2,figsize=(6,6))
# ----> 8 xs[0].plot(hindi,'ro-')
#       9 xs[1].plot(english,'bo-')
#      10 xs[2].plot(maths,'go-')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
fig, axs =plt.subplots(1,3,figsize=(15,3))
axs[0].plot(y1,'r--')
axs[1].plot(y2,'b--')
axs[2].plot(y3,'g--')

# %%
x=np.arange(40,100,10)
hindi=np.array([50,60,40,70,80,50])
english=np.array([70,80,55,60,70,90])
maths=np.array([60,80,50,85,60,75])
physics=np.array([60,70,40,45,90,65])

fig, xs=plt.subplots(2,2,figsize=(6,6))
xs[0].plot(hindi,'ro-')
xs[1].plot(english,'bo-')
xs[2].plot(maths,'go-')
xs[3].plot(physics,'yo-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 8
#       5 physics=np.array([60,70,40,45,90,65])
#       7 fig, xs=plt.subplots(2,2,figsize=(6,6))
# ----> 8 xs[0].plot(hindi,'ro-')
#       9 xs[1].plot(english,'bo-')
#      10 xs[2].plot(maths,'go-')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
x=np.arange(40,100,10)
hindi=np.array([50,60,40,70,80,50])
english=np.array([70,80,55,60,70,90])
maths=np.array([60,80,50,85,60,75])
physics=np.array([60,70,40,45,90,65])
fig, axs =plt.subplots(2,2,figsize=(15,7))
axs[0][0].plot(x,hindi,'r*-')
axs[0][0].set_title('Hindi')
axs[0][1].set_title('English')
axs[1][0].set_title('Maths')
axs[1][1].set_title('Physics')
axs[0][1].plot(x,english,'b^-')
axs[1][0].plot(x,maths,'go-')
axs[1][1].plot(x,physics,'ys-')

# %%
hindi=np.array([50,60,40,70,80,50])
english=np.array([70,80,55,60,70,90])
maths=np.array([60,80,50,85,60,75])
physics=np.array([60,70,40,45,90,65])

fig,axx= plt.subplots(2,2,figsize=(20,5))
axx[0][0].plot(hindi,'ro-',label='hindi')
axx[0][0].set_title('hindi')
axx[0][0].grid()
axx[0][0].legend()
axx[0][1].plot(english,'b*-', label='english')
axx[0][1].grid()
axx[1][1].grid()
axx[1][0].grid()
axx[0][1].legend()
axx[0][1].set_title('english')   
axx[1][0].set_title('maths')
axx[1][1].set_title('physics')
axx[1][0].plot(maths,'gs-',label="maths")
axx[1][1].plot(physics,'y^-', label="physics")
axx[1][0].legend() 
axx[1][1].legend() 
plt.show()
plt.savefig('fig1.png',bbox_inches='tight')

# %%
x=np.array([1,2,3,4,5])
hindi=np.array([10,40,20,30,50])
plt.bar(x,hindi)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
hindi=np.array([10,40,20,30,50])
plt.bar(x,hindi)
plt.show()
hindi=np.array([10,40,20,30,50])
plt.bar(x,hindi)
plt.show()

# %%
x=np.array(['ajay','aryan','ankit','ankur','akash'])
hindi=np.array([40,60,80,55,75])
english=np.array([75,65,85,50,70])
maths=np.array([80,90,55,67,78])
physics=np.array([90,55,67,87,60])
fig,ax=plt.subplots(2,2,figsize=(10,5))
ax[0][0].bar(x,hindi,color='red',width=0.5,label='hindi')
ax[0][0].legend()
ax[0][1].bar(x,english,color='green',width=0.5,label='english')
ax[0][1].legend()
ax[1][0].bar(x,maths,color='blue',width=0.5,label='maths')
ax[1][0].legend()
ax[1][1].bar(x,physics,color='yellow',width=0.5,label='physics')
ax[1][1].legend()
plt.show()

# %%
x=np.array([25,40,20,10,5])
plt.pie(x,autopct='%.1f%%')
plt.show()
