# %%
import matplotlib.pyplot as plt # basic graphs
import numpy as np
import pandas as pd
import seaborn as sns # advanced graphs
import plotly.express as px # interactive graphs

# %%
# practice datasets

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
iris=sns.load_dataset('iris') #about iris flower
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - single column with number
#     - stats
#         - histogram
#         - boxplot
#         - density plot (KDE)
#     - discrete
#         - line plot
#         - area chart
#         - bar chart
# - 2 or 3 columns with numbers
#     - relationship
#         - scatter plot
#         - bubble chart(scatter plot with size)
#         - heat map
#         - hexagonal bin plot
#     - composition
#         - stacked bar chart
#         - stacked area chart
#         - grouped line chart

# %%
plt.hist('sepal_length', data=iris, bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %%
_=plt.hist('sepal_length', data=iris, bins=20)

# %%
_=plt.hist('sepal_width', data=iris, bins=25)

# %%
plt.hist('petal_length', data=iris, bins=25)
# Out:
# (array([ 4., 20., 24.,  2.,  0.,  0.,  0.,  0.,  1.,  2.,  2.,  3.,  8.,
#          9., 12.,  8., 13., 10.,  4., 12.,  5.,  5.,  2.,  1.,  3.]),
#  array([1.   , 1.236, 1.472, 1.708, 1.944, 2.18 , 2.416, 2.652, 2.888,
#         3.124, 3.36 , 3.596, 3.832, 4.068, 4.304, 4.54 , 4.776, 5.012,
#         5.248, 5.484, 5.72 , 5.956, 6.192, 6.428, 6.664, 6.9  ]),
#  <BarContainer object of 25 artists>)

# %%
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_1084\2414357448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
fig,axs=plt.subplots(2,2,figsize=(10,10), layout='constrained')
axs[0][0].hist('petal_width', data=iris, bins=25, color='red', label='petal_width')
axs[0][0].legend()
axs[0][0].set_title('petal_width')



axs[0][1].hist('petal_length', data=iris, bins=25, color='blue', label='petal_length')
axs[0][1].legend()
axs[0][1].set_title('petal_length')



axs[1][0].hist('sepal_length', data=iris, bins=20, color='green', label='sepal_length')
axs[1][0].legend()
axs[1][0].set_title('sepal_length')



axs[1][1].hist('sepal_width', data=iris, bins=20, color='yellow', label='sepal_width')
axs[1][1].legend()
axs[1][1].set_title('sepal_width')
plt.show()

# %%
plt.boxplot('sepal_length', data=iris, notch= True, vert=False)
plt.show()

# %%
plt.plot('sepal_length', data=iris, marker='o', color='blue', linestyle='--', mfc='red')

# %%
plt.plot?
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...
