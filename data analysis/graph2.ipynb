# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic['survived'].unique())
# Out:
# [0 1]

# %%
print(titanic['pclass'].unique())
# Out:
# [3 1 2]

# %%
print(titanic['age'].unique())
# Out:
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]

# %%
print(titanic['age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# - Categorial graphs
#     - columns that have text are generally categorial
#     - the first step is to count the numbers of uique values in the column
#     - then plot the count of each category
#     - following charts are a good way to visualize categorial data
#         - bar chart
#         - pie chart
#         - donut chart
#         - line chart(when too many categories)
#         - area chart(when too many categories)

# %%
survival_count= titanic['alive'].value_counts()
survival_count
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
survival_count.plot(kind='pie',autopct='%.1f%%',title='Survival Rate')
# Out:
# <Axes: title={'center': 'Survival Rate'}, ylabel='count'>

# %%
survival_count.plot(
    kind='pie',
    autopct='%1.1f%%',
    title='Survival Rate',
    labels=['Survived', 'Not Survived'],
    colors=['#66b3ff','#ff9999'],
    labeldistance=1.1,
    wedgeprops = {
        'width':0.6,
        'edgecolor':'red',
        'linewidth':1.5,
        'linestyle':'dashdot',
})
# Out:
# <Axes: title={'center': 'Survival Rate'}, ylabel='count'>

# %% [markdown]
# seaborn
#     - for complex data visualization using simple code

# %%
sns.countplot(data=titanic, x='alive', hue='sex')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=titanic,y='alive',hue='pclass')
# Out:
# <Axes: xlabel='count', ylabel='alive'>

# %%
sns.jointplot(data='titanic', x='fare', y='age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sns.jointplot(data='titanic', x='fare', y='age')
#
# File c:\Users\Utkarsh\miniconda3\lib\site-packages\seaborn\axisgrid.py:2241, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2238     dropna = True
#    2240 # Initialize the JointGrid object
# -> 2241 grid = JointGrid(
#    2242     data=data, x=x, y=y, hue=hue,
#    2243     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2244     dropna=dropna, height=height, ratio=ratio, space=space,
#    2245     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2246 )
#    2248 if grid.hue is not None:
#    2249     marginal_kws.setdefault("legend", False)
#
# ...

# %%
dots=sns.load_dataset('dots')
sns.relplot(
    data=dots,
    x='time',
    y='firing_rate',
    hue='choice',
    row='align',
    col='choice',
    kind='line',
    size='coherence',
    style='choice',
)
# Out:
# c:\Users\Utkarsh\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# c:\Users\Utkarsh\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
