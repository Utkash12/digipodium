# %% [markdown]
# - run this command in the terminal
#  pip install pandas openpyxl --upgrade

# %% [markdown]
# - Grouping and Aggregating

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
file='Canada.xlsx'
canada=pd.read_excel(file, sheet_name=1,skiprows=20,skipfooter=2)

# %%
canada['AreaName']  # Series  -only 1 column(1 Dimensional)
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: AreaName, Length: 195, dtype: object

# %%
canada  # data frame - 2D data structure
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 0         Southern Asia  902  Developing regions    16    39    39    47
# ...

# %%
canada.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 0  902  Developing regions    16    39    39    47    71   340   496   741
# 1  901   Developed regions     1     0     0     0     0     0     1     2
#
#    1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 0   828  1076  1028  1378  1170   713   858  1537  2212  2555  1999  2395
# 1     2     3     3    21    56    96    71    63   113   307   574  1264
#
#    2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# 0  3326  4067  3697  3479  2978  3436  3009  2652  2111  1746  1758  2203
# 1  1816  1602  1021   853  1450  1223   856   702   560   716   561   539
#
#    2012  2013
# 0  2635  2004
# 1   620   603

# %%
canada.tail(6)
# Out:
#            Type    Coverage                              OdName  AREA  \
# 189  Immigrants  Foreigners  Venezuela (Bolivarian Republic of)   904
# 190  Immigrants  Foreigners                            Viet Nam   935
# 191  Immigrants  Foreigners                      Western Sahara   903
# 192  Immigrants  Foreigners                               Yemen   935
# 193  Immigrants  Foreigners                              Zambia   903
# 194  Immigrants  Foreigners                            Zimbabwe   903
#
#                             AreaName  REG             RegName  DEV  \
# 189  Latin America and the Caribbean  931       South America  902
# 190                             Asia  920  South-Eastern Asia  902
# 191                           Africa  912     Northern Africa  902
# 192                             Asia  922        Western Asia  902
# 193                           Africa  910      Eastern Africa  902
# 194                           Africa  910      Eastern Africa  902
#
# ...

# %%
canada.sample(9)
# Out:
#            Type    Coverage                                 OdName  AREA  \
# 105  Immigrants  Foreigners                               Malaysia   935
# 55   Immigrants  Foreigners                                  Egypt   903
# 122  Immigrants  Foreigners                            Netherlands   908
# 158  Immigrants  Foreigners                               Slovenia   908
# 78   Immigrants  Foreigners                                Iceland   908
# 48   Immigrants  Foreigners  Democratic People's Republic of Korea   935
# 174  Immigrants  Foreigners                                  Tonga   909
# 114  Immigrants  Foreigners                               Mongolia   935
# 35   Immigrants  Foreigners                                  Chile   904
#
#                             AreaName  REG             RegName  DEV  \
# 105                             Asia  920  South-Eastern Asia  902
# 55                            Africa  912     Northern Africa  902
# ...

# %%
canada[5:10:2]
# Out:
#          Type    Coverage     OdName  AREA                         AreaName  \
# 5  Immigrants  Foreigners     Angola   903                           Africa
# 7  Immigrants  Foreigners  Argentina   904  Latin America and the Caribbean
# 9  Immigrants  Foreigners  Australia   909                          Oceania
#
#    REG                    RegName  DEV             DevName  1980  1981  1982  \
# 5  911              Middle Africa  902  Developing regions     1     3     6
# 7  931              South America  902  Developing regions   368   426   626
# 9  927  Australia and New Zealand  901   Developed regions   702   639   484
#
#    1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# 5     6     4     3     5     5    11     6     8    23    26    22     8
# 7   241   237   196   213   519   374   538   678   763  1023  1022   366
# 9   317   317   319   356   467   410   553   620   640   734   886   702
#
# ...

# %%
canada['RegName']  # dict-like access to a Series
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: RegName, Length: 195, dtype: object

# %%
canada.RegName   # object style access
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: RegName, Length: 195, dtype: object

# %%
cols=list(range(1980,1991))
canada[cols[:5]]
# Out:
#      1980  1981  1982  1983  1984
# 0      16    39    39    47    71
# 1       1     0     0     0     0
# 2      80    67    71    69    63
# 3       0     1     0     0     0
# 4       0     0     0     0     0
# ..    ...   ...   ...   ...   ...
# 190  1191  1829  2162  3404  7583
# 191     0     0     0     0     0
# 192     1     2     1     6     0
# 193    11    17    11     7    16
# 194    72   114   102    44    32
#
# [195 rows x 5 columns]

# %%
cols=list(range(1980,1991))
canada[cols].head()
# Out:
#    1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0    16    39    39    47    71   340   496   741   828  1076  1028
# 1     1     0     0     0     0     0     1     2     2     3     3
# 2    80    67    71    69    63    44    69   132   242   434   491
# 3     0     1     0     0     0     0     0     1     0     1     2
# 4     0     0     0     0     0     0     2     0     0     0     3

# %%
canada[['AreaName','RegName',2013]].head(10)
# Out:
#                           AreaName                    RegName  2013
# 0                             Asia              Southern Asia  2004
# 1                           Europe            Southern Europe   603
# 2                           Africa            Northern Africa  4331
# 3                          Oceania                  Polynesia     0
# 4                           Europe            Southern Europe     1
# 5                           Africa              Middle Africa    45
# 6  Latin America and the Caribbean                  Caribbean    25
# 7  Latin America and the Caribbean              South America   282
# 8                             Asia               Western Asia   207
# 9                          Oceania  Australia and New Zealand  1121

# %%
canada[['Type','Coverage','DEV']].sample(10)
# Out:
#            Type    Coverage  DEV
# 87   Immigrants  Foreigners  901
# 61   Immigrants  Foreigners  902
# 92   Immigrants  Foreigners  902
# 126  Immigrants  Foreigners  902
# 140  Immigrants  Foreigners  902
# 133  Immigrants  Foreigners  902
# 162  Immigrants  Foreigners  902
# 28   Immigrants  Foreigners  902
# 104  Immigrants  Foreigners  902
# 172  Immigrants  Foreigners  901

# %%
canada.set_index('OdName')
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  1982  \
# OdName
# Afghanistan          Southern Asia  902  Developing regions    16    39    39
# ...

# %%
canada.set_index('OdName', inplace=True)

# %%
canada.iloc[100]  #101st row
# Out:
# Type               Immigrants
# Coverage           Foreigners
# AREA                      908
# AreaName               Europe
# REG                       926
# RegName        Western Europe
# DEV                       901
# DevName     Developed regions
# 1980                        1
# 1981                        4
# 1982                        2
# 1983                        0
# 1984                        0
# 1985                        3
# 1986                        0
# 1987                        1
# 1988                        1
# 1989                        1
# 1990                        0
# 1991                        1
# 1992                        2
# 1993                        3
# 1994                        1
# 1995                        0
# 1996                        7
# 1997                        2
# 1998                        0
# 1999                        2
# 2000                        0
# 2001                        2
# 2002                        0
# ...

# %%
canada.iloc[10:20, 2:9]
# Out:
#             AREA                         AreaName   REG          RegName  DEV  \
# OdName
# Austria      908                           Europe   926   Western Europe  901
# Azerbaijan   935                             Asia   922     Western Asia  902
# Bahamas      904  Latin America and the Caribbean   915        Caribbean  902
# Bahrain      935                             Asia   922     Western Asia  902
# Bangladesh   935                             Asia  5501    Southern Asia  902
# Barbados     904  Latin America and the Caribbean   915        Caribbean  902
# Belarus      908                           Europe   923   Eastern Europe  901
# Belgium      908                           Europe   926   Western Europe  901
# Belize       904  Latin America and the Caribbean   916  Central America  902
# Benin        903                           Africa   914   Western Africa  902
#
#                        DevName  1980
# OdName
# Austria      Developed regions   234
# ...

# %%
canada.loc['Japan']
# Out:
# Type               Immigrants
# Coverage           Foreigners
# AREA                      935
# AreaName                 Asia
# REG                       906
# RegName          Eastern Asia
# DEV                       901
# DevName     Developed regions
# 1980                      701
# 1981                      756
# 1982                      598
# 1983                      309
# 1984                      246
# 1985                      198
# 1986                      248
# 1987                      422
# 1988                      324
# 1989                      494
# 1990                      379
# 1991                      506
# 1992                      605
# 1993                      907
# 1994                      956
# 1995                      826
# 1996                      994
# 1997                      924
# 1998                      897
# 1999                     1083
# 2000                     1010
# 2001                     1092
# 2002                      806
# ...

# %%
vs=canada.loc[['Japan','France',"India"]],[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990]

# %%
years=list(range(1980,2014))
canada[years].sum(axis=1)
# Out:
# OdName
# Afghanistan       58639
# Albania           15699
# Algeria           69439
# American Samoa        6
# Andorra              15
#                   ...
# Viet Nam          97146
# Western Sahara        2
# Yemen              2985
# Zambia             1677
# Zimbabwe           8598
# Length: 195, dtype: int64

# %%
canada['Total']=canada[years].sum(axis=1)
canada.head()
canada['Total']
# Out:
# OdName
# Afghanistan       58639
# Albania           15699
# Algeria           69439
# American Samoa        6
# Andorra              15
#                   ...
# Viet Nam          97146
# Western Sahara        2
# Yemen              2985
# Zambia             1677
# Zimbabwe           8598
# Name: Total, Length: 195, dtype: int64

# %%
canada['Faltu']=10
canada
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  1982  \
# OdName
# Afghanistan          Southern Asia  902  Developing regions    16    39    39
# ...

# %%
canada['Coverage'].nunique()
# Out:
# 2

# %%
canada.drop(columns="Faltu",inplace=True)
canada.head(2)
# Out:
#                    Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan  Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania      Immigrants  Foreigners   908   Europe   925  Southern Europe
#
#              DEV             DevName  1980  1981  1982  1983  1984  1985  \
# OdName
# Afghanistan  902  Developing regions    16    39    39    47    71   340
# Albania      901   Developed regions     1     0     0     0     0     0
#
#              1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# OdName
# Afghanistan   496   741   828  1076  1028  1378  1170   713   858  1537  2212
# Albania         1     2     2     3     3    21    56    96    71    63   113
#
#              1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  \
# OdName
# Afghanistan  2555  1999  2395  3326  4067  3697  3479  2978  3436  3009  2652
# Albania       307   574  1264  1816  1602  1021   853  1450  1223   856   702
#
# ...

# %%
cols_to_drop=['Type',"Coverage","AREA","REG","DEV"]
canada.drop(columns=cols_to_drop,inplace=True)
canada.head(5)
# Out:
#                AreaName          RegName             DevName  1980  1981  \
# OdName
# Afghanistan        Asia    Southern Asia  Developing regions    16    39
# Albania          Europe  Southern Europe   Developed regions     1     0
# Algeria          Africa  Northern Africa  Developing regions    80    67
# American Samoa  Oceania        Polynesia  Developing regions     0     1
# Andorra          Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  \
# OdName
# Afghanistan       39    47    71   340   496   741   828  1076  1028  1378
# Albania            0     0     0     0     1     2     2     3     3    21
# Algeria           71    69    63    44    69   132   242   434   491   872
# American Samoa     0     0     0     0     0     1     0     1     2     0
# Andorra            0     0     0     0     2     0     0     0     3     0
#
# ...

# %%
canada.rename(mapper={
    'AreaName': 'Continent',
    'RegName': 'Region',
    'DevName': 'Status'
}, axis=1, inplace=True)
canada.head(5)
# Out:
#                Continent           Region              Status  1980  1981  \
# OdName
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  \
# OdName
# Afghanistan       39    47    71   340   496   741   828  1076  1028  1378
# Albania            0     0     0     0     1     2     2     3     3    21
# Algeria           71    69    63    44    69   132   242   434   491   872
# American Samoa     0     0     0     0     0     1     0     1     2     0
# Andorra            0     0     0     0     2     0     0     0     3     0
#
# ...

# %%
canada.replace('Developing regions', 0, inplace=True)
canada.replace('Developed regions', 1, inplace=True)

# %%
canada.head()
# Out:
#                Continent           Region  Status  1980  1981  1982  1983  \
# OdName
# Afghanistan         Asia    Southern Asia       0    16    39    39    47
# Albania           Europe  Southern Europe       1     1     0     0     0
# Algeria           Africa  Northern Africa       0    80    67    71    69
# American Samoa   Oceania        Polynesia       0     0     1     0     0
# Andorra           Europe  Southern Europe       1     0     0     0     0
#
#                 1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  \
# OdName
# Afghanistan       71   340   496   741   828  1076  1028  1378  1170   713
# Albania            0     0     1     2     2     3     3    21    56    96
# Algeria           63    44    69   132   242   434   491   872   795   717
# American Samoa     0     0     0     1     0     1     2     0     0     0
# Andorra            0     0     2     0     0     0     3     0     1     0
#
# ...

# %%
canada['Total'].apply(lambda x: x> 160000).astype(int).plot(kind='pie')
# Out:
# <Axes: ylabel='Total'>

# %%
canada.Total
# Out:
# OdName
# Afghanistan       58639
# Albania           15699
# Algeria           69439
# American Samoa        6
# Andorra              15
#                   ...
# Viet Nam          97146
# Western Sahara        2
# Yemen              2985
# Zambia             1677
# Zimbabwe           8598
# Name: Total, Length: 195, dtype: int64

# %%
canada['Total'].apply(lambda x: x>50000).value_counts()
# Out:
# Total
# False    163
# True      32
# Name: count, dtype: int64

# %%
penguins= sns.load_dataset("penguins")
penguins['body_mass_g'].plot(kind='hist', bins=3,)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.cut(penguins['body_mass_g'],3).unique()
# Out:
# [(2696.4, 3900.0], NaN, (3900.0, 5100.0], (5100.0, 6300.0]]
# Categories (3, interval[float64, right]): [(2696.4, 3900.0] < (3900.0, 5100.0] < (5100.0, 6300.0]]

# %%
pd.cut(penguins['body_mass_g'],3)
# Out:
# 0      (2696.4, 3900.0]
# 1      (2696.4, 3900.0]
# 2      (2696.4, 3900.0]
# 3                   NaN
# 4      (2696.4, 3900.0]
#              ...
# 339                 NaN
# 340    (3900.0, 5100.0]
# 341    (5100.0, 6300.0]
# 342    (5100.0, 6300.0]
# 343    (5100.0, 6300.0]
# Name: body_mass_g, Length: 344, dtype: category
# Categories (3, interval[float64, right]): [(2696.4, 3900.0] < (3900.0, 5100.0] < (5100.0, 6300.0]]

# %%
def categorize_by_weight(value):
    if value == np.nan:
         return np.nan
    elif value < 3900:
        return 'Light Weight'
    elif value >= 3900 and value < 5100:
        return 'Medium Weight'
    elif value >= 5100:
        return 'Heavy Weight'

penguins['category']=penguins['body_mass_g'].apply(categorize_by_weight)

# %%
summ=lambda x,y: x+y
print(summ(2,3))
# Out:
# 5

# %%
def sum(x, y):
    return x + y
print(sum(1, 2))
# Out:
# 3

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex       category
# 0         3750.0    Male   Light Weight
# ...

# %%
penguins.groupby('species').get_group('Adelie')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex       category
# 0         3750.0    Male   Light Weight
# ...

# %%
np.set_printoptions(precision=3)
pd.set_option('display.precision',2)

# %%
penguins.groupby(['species','island','sex'])[['bill_length_mm','body_mass_g']].mean()
# Out:
#                             bill_length_mm  body_mass_g
# species   island    sex
# Adelie    Biscoe    Female           37.36      3369.32
#                     Male             40.59      4050.00
#           Dream     Female           36.91      3344.44
#                     Male             40.07      4045.54
#           Torgersen Female           37.55      3395.83
#                     Male             40.59      4034.78
# Chinstrap Dream     Female           46.57      3527.21
#                     Male             51.09      3938.97
# Gentoo    Biscoe    Female           45.56      4679.74
#                     Male             49.47      5484.84

# %%
penguins.groupby(['species','island','sex'])[['bill_length_mm','body_mass_g']].mean().reset_index()
# Out:
#      species     island     sex  bill_length_mm  body_mass_g
# 0     Adelie     Biscoe  Female           37.36      3369.32
# 1     Adelie     Biscoe    Male           40.59      4050.00
# 2     Adelie      Dream  Female           36.91      3344.44
# 3     Adelie      Dream    Male           40.07      4045.54
# 4     Adelie  Torgersen  Female           37.55      3395.83
# 5     Adelie  Torgersen    Male           40.59      4034.78
# 6  Chinstrap      Dream  Female           46.57      3527.21
# 7  Chinstrap      Dream    Male           51.09      3938.97
# 8     Gentoo     Biscoe  Female           45.56      4679.74
# 9     Gentoo     Biscoe    Male           49.47      5484.84

# %%
penguins.groupby('species')['bill_length_mm'].mean()
# Out:
# species
# Adelie       38.79
# Chinstrap    48.83
# Gentoo       47.50
# Name: bill_length_mm, dtype: float64

# %%
print(penguins.groupby('species'))

# %%
# print(penguins.groupby('bill_length_mm').mean())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\Utkarsh\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File c:\Users\Utkarsh\miniconda3\lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
penguins.groupby('species')['bill_length_mm'].sum()
# Out:
# species
# Adelie       5857.5
# Chinstrap    3320.7
# Gentoo       5843.1
# Name: bill_length_mm, dtype: float64

# %%
penguins.groupby('species')[['bill_length_mm','body_mass_g']].sum()
# Out:
#            bill_length_mm  body_mass_g
# species
# Adelie             5857.5     558800.0
# Chinstrap          3320.7     253850.0
# Gentoo             5843.1     624350.0

# %%
penguins.groupby('island')[['bill_length_mm','body_mass_g']].sum()
# Out:
#            bill_length_mm  body_mass_g
# island
# Biscoe             7558.0     787575.0
# Dream              5476.8     460400.0
# Torgersen          1986.5     189025.0

# %%
penguins.pivot_table(values='body_mass_g',index='species',columns='island')
# Out:
# island      Biscoe    Dream  Torgersen
# species
# Adelie     3709.66  3688.39    3706.37
# Chinstrap      NaN  3733.09        NaN
# Gentoo     5076.02      NaN        NaN

# %%
pp=penguins.pivot_table(values='body_mass_g',index='species',columns='island',aggfunc='sum')
pp
# Out:
# island       Biscoe     Dream  Torgersen
# species
# Adelie     163225.0  206550.0   189025.0
# Chinstrap       NaN  253850.0        NaN
# Gentoo     624350.0       NaN        NaN

# %%
pp.replace(np.NaN,0)
# Out:
# island       Biscoe     Dream  Torgersen
# species
# Adelie     163225.0  206550.0   189025.0
# Chinstrap       0.0  253850.0        0.0
# Gentoo     624350.0       0.0        0.0

# %%
pp.replace(np.nan, 0, inplace=True)
pp=pp.astype(int)
pp
# Out:
# island     Biscoe   Dream  Torgersen
# species
# Adelie     163225  206550     189025
# Chinstrap       0  253850          0
# Gentoo     624350       0          0

# %%
groupdf=penguins.groupby(['species','island','sex'])[['bill_length_mm','body_mass_g']].mean().reset_index()

# %%
groupdf.sort_values('body_mass_g')
# Out:
#      species     island     sex  bill_length_mm  body_mass_g
# 2     Adelie      Dream  Female           36.91      3344.44
# 0     Adelie     Biscoe  Female           37.36      3369.32
# 4     Adelie  Torgersen  Female           37.55      3395.83
# 6  Chinstrap      Dream  Female           46.57      3527.21
# 7  Chinstrap      Dream    Male           51.09      3938.97
# 5     Adelie  Torgersen    Male           40.59      4034.78
# 3     Adelie      Dream    Male           40.07      4045.54
# 1     Adelie     Biscoe    Male           40.59      4050.00
# 8     Gentoo     Biscoe  Female           45.56      4679.74
# 9     Gentoo     Biscoe    Male           49.47      5484.84

# %%
groupdf.sort_values('body_mass_g', ascending=False)
# Out:
#      species     island     sex  bill_length_mm  body_mass_g
# 9     Gentoo     Biscoe    Male           49.47      5484.84
# 8     Gentoo     Biscoe  Female           45.56      4679.74
# 1     Adelie     Biscoe    Male           40.59      4050.00
# 3     Adelie      Dream    Male           40.07      4045.54
# 5     Adelie  Torgersen    Male           40.59      4034.78
# 7  Chinstrap      Dream    Male           51.09      3938.97
# 6  Chinstrap      Dream  Female           46.57      3527.21
# 4     Adelie  Torgersen  Female           37.55      3395.83
# 0     Adelie     Biscoe  Female           37.36      3369.32
# 2     Adelie      Dream  Female           36.91      3344.44

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
car_crashes=sns.load_dataset('car_crashes')
car_crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8      7.33     5.64           18.05        15.04       784.55
# 1   18.1      7.42     4.53           16.29        17.01      1053.48
# 2   18.6      6.51     5.21           15.62        17.86       899.47
# 3   22.4      4.03     5.82           21.06        21.28       827.34
# 4   12.0      4.20     3.36           10.92        10.68       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
car_crashes.drop(columns='abbrev')
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8      7.33     5.64           18.05        15.04       784.55
# 1    18.1      7.42     4.53           16.29        17.01      1053.48
# 2    18.6      6.51     5.21           15.62        17.86       899.47
# 3    22.4      4.03     5.82           21.06        21.28       827.34
# 4    12.0      4.20     3.36           10.92        10.68       878.41
# 5    13.6      5.03     3.81           10.74        12.92       835.50
# 6    10.8      4.97     3.89            9.40         8.86      1068.73
# 7    16.2      6.16     4.86           14.09        16.04      1137.87
# 8     5.9      2.01     1.59            5.90         5.90      1273.89
# 9    17.9      3.76     5.19           16.47        16.83      1160.13
# 10   15.6      2.96     3.90           14.82        14.51       913.15
# 11   17.5      9.45     7.17           14.35        15.22       861.18
# ...

# %%
car_crashes.drop(columns=['abbrev'], inplace='True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 car_crashes.drop(columns=['abbrev'], inplace='True')
#
# File c:\Users\Utkarsh\miniconda3\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...
