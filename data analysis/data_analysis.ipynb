# %% [markdown]
# - run this command in the terminal
#  pip install pandas openpyxl --upgrade

# %% [markdown]
# - Grouping and Aggregating

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns',None)

# %%
file='Canada.xlsx'
canada=pd.read_excel(file, sheet_name=1,skiprows=20,skipfooter=2)

# %%
canada['AreaName']  # Series  -only 1 column(1 Dimensional)
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: AreaName, Length: 195, dtype: object

# %%
canada  # data frame - 2D data structure
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 0         Southern Asia  902  Developing regions    16    39    39    47
# ...

# %%
canada.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 0  902  Developing regions    16    39    39    47    71   340   496   741
# 1  901   Developed regions     1     0     0     0     0     0     1     2
#
#    1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 0   828  1076  1028  1378  1170   713   858  1537  2212  2555  1999  2395
# 1     2     3     3    21    56    96    71    63   113   307   574  1264
#
#    2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# 0  3326  4067  3697  3479  2978  3436  3009  2652  2111  1746  1758  2203
# 1  1816  1602  1021   853  1450  1223   856   702   560   716   561   539
#
#    2012  2013
# 0  2635  2004
# 1   620   603

# %%
canada.tail(6)
# Out:
#            Type    Coverage                              OdName  AREA  \
# 189  Immigrants  Foreigners  Venezuela (Bolivarian Republic of)   904
# 190  Immigrants  Foreigners                            Viet Nam   935
# 191  Immigrants  Foreigners                      Western Sahara   903
# 192  Immigrants  Foreigners                               Yemen   935
# 193  Immigrants  Foreigners                              Zambia   903
# 194  Immigrants  Foreigners                            Zimbabwe   903
#
#                             AreaName  REG             RegName  DEV  \
# 189  Latin America and the Caribbean  931       South America  902
# 190                             Asia  920  South-Eastern Asia  902
# 191                           Africa  912     Northern Africa  902
# 192                             Asia  922        Western Asia  902
# 193                           Africa  910      Eastern Africa  902
# 194                           Africa  910      Eastern Africa  902
#
# ...

# %%
canada.sample(9)
# Out:
#            Type    Coverage                              OdName  AREA  \
# 73   Immigrants  Foreigners                       Guinea-Bissau   903
# 189  Immigrants  Foreigners  Venezuela (Bolivarian Republic of)   904
# 71   Immigrants  Foreigners                           Guatemala   904
# 114  Immigrants  Foreigners                            Mongolia   935
# 90   Immigrants  Foreigners                               Kenya   903
# 81   Immigrants  Foreigners          Iran (Islamic Republic of)   935
# 79   Immigrants  Foreigners                               India   935
# 145  Immigrants  Foreigners               Saint Kitts and Nevis   904
# 148  Immigrants  Foreigners                               Samoa   909
#
#                             AreaName   REG          RegName  DEV  \
# 73                            Africa   914   Western Africa  902
# 189  Latin America and the Caribbean   931    South America  902
# 71   Latin America and the Caribbean   916  Central America  902
# ...

# %%
canada[5:10:2]
# Out:
#          Type    Coverage     OdName  AREA                         AreaName  \
# 5  Immigrants  Foreigners     Angola   903                           Africa
# 7  Immigrants  Foreigners  Argentina   904  Latin America and the Caribbean
# 9  Immigrants  Foreigners  Australia   909                          Oceania
#
#    REG                    RegName  DEV             DevName  1980  1981  1982  \
# 5  911              Middle Africa  902  Developing regions     1     3     6
# 7  931              South America  902  Developing regions   368   426   626
# 9  927  Australia and New Zealand  901   Developed regions   702   639   484
#
#    1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# 5     6     4     3     5     5    11     6     8    23    26    22     8
# 7   241   237   196   213   519   374   538   678   763  1023  1022   366
# 9   317   317   319   356   467   410   553   620   640   734   886   702
#
# ...

# %%
canada['RegName']  # dict-like access to a Series
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: RegName, Length: 195, dtype: object

# %%
canada.RegName   # object style access
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: RegName, Length: 195, dtype: object

# %%
cols=list(range(1980,1991))
canada[cols[:5]]
# Out:
#      1980  1981  1982  1983  1984
# 0      16    39    39    47    71
# 1       1     0     0     0     0
# 2      80    67    71    69    63
# 3       0     1     0     0     0
# 4       0     0     0     0     0
# ..    ...   ...   ...   ...   ...
# 190  1191  1829  2162  3404  7583
# 191     0     0     0     0     0
# 192     1     2     1     6     0
# 193    11    17    11     7    16
# 194    72   114   102    44    32
#
# [195 rows x 5 columns]

# %%
cols=list(range(1980,1991))
canada[cols].head()
# Out:
#    1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0    16    39    39    47    71   340   496   741   828  1076  1028
# 1     1     0     0     0     0     0     1     2     2     3     3
# 2    80    67    71    69    63    44    69   132   242   434   491
# 3     0     1     0     0     0     0     0     1     0     1     2
# 4     0     0     0     0     0     0     2     0     0     0     3

# %%
canada[['AreaName','RegName',2013]].head(10)
# Out:
#                           AreaName                    RegName  2013
# 0                             Asia              Southern Asia  2004
# 1                           Europe            Southern Europe   603
# 2                           Africa            Northern Africa  4331
# 3                          Oceania                  Polynesia     0
# 4                           Europe            Southern Europe     1
# 5                           Africa              Middle Africa    45
# 6  Latin America and the Caribbean                  Caribbean    25
# 7  Latin America and the Caribbean              South America   282
# 8                             Asia               Western Asia   207
# 9                          Oceania  Australia and New Zealand  1121

# %%
canada[['Type','Coverage','DEV']].sample(10)
# Out:
#            Type    Coverage  DEV
# 137  Immigrants  Foreigners  901
# 95   Immigrants  Foreigners  901
# 45   Immigrants  Foreigners  902
# 18   Immigrants  Foreigners  902
# 185  Immigrants  Foreigners  901
# 10   Immigrants  Foreigners  901
# 146  Immigrants  Foreigners  902
# 175  Immigrants  Foreigners  902
# 4    Immigrants  Foreigners  901
# 54   Immigrants  Foreigners  902

# %%
canada.set_index('OdName')
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  1982  \
# OdName
# Afghanistan          Southern Asia  902  Developing regions    16    39    39
# ...

# %%
canada.set_index('OdName', inplace=True)

# %%
canada.iloc[100]  #101st row
# Out:
# Type               Immigrants
# Coverage           Foreigners
# AREA                      908
# AreaName               Europe
# REG                       926
# RegName        Western Europe
# DEV                       901
# DevName     Developed regions
# 1980                        1
# 1981                        4
# 1982                        2
# 1983                        0
# 1984                        0
# 1985                        3
# 1986                        0
# 1987                        1
# 1988                        1
# 1989                        1
# 1990                        0
# 1991                        1
# 1992                        2
# 1993                        3
# 1994                        1
# 1995                        0
# 1996                        7
# 1997                        2
# 1998                        0
# 1999                        2
# 2000                        0
# 2001                        2
# 2002                        0
# ...

# %%
canada.iloc[10:20, 2:9]
# Out:
#             AREA                         AreaName   REG          RegName  DEV  \
# OdName
# Austria      908                           Europe   926   Western Europe  901
# Azerbaijan   935                             Asia   922     Western Asia  902
# Bahamas      904  Latin America and the Caribbean   915        Caribbean  902
# Bahrain      935                             Asia   922     Western Asia  902
# Bangladesh   935                             Asia  5501    Southern Asia  902
# Barbados     904  Latin America and the Caribbean   915        Caribbean  902
# Belarus      908                           Europe   923   Eastern Europe  901
# Belgium      908                           Europe   926   Western Europe  901
# Belize       904  Latin America and the Caribbean   916  Central America  902
# Benin        903                           Africa   914   Western Africa  902
#
#                        DevName  1980
# OdName
# Austria      Developed regions   234
# ...

# %%
canada.loc['Japan']
# Out:
# Type               Immigrants
# Coverage           Foreigners
# AREA                      935
# AreaName                 Asia
# REG                       906
# RegName          Eastern Asia
# DEV                       901
# DevName     Developed regions
# 1980                      701
# 1981                      756
# 1982                      598
# 1983                      309
# 1984                      246
# 1985                      198
# 1986                      248
# 1987                      422
# 1988                      324
# 1989                      494
# 1990                      379
# 1991                      506
# 1992                      605
# 1993                      907
# 1994                      956
# 1995                      826
# 1996                      994
# 1997                      924
# 1998                      897
# 1999                     1083
# 2000                     1010
# 2001                     1092
# 2002                      806
# ...

# %%
vs=canada.loc[['Japan','France',"India"]],[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990]

# %%
years=list(range(1980,2014))
canada[years].sum()
# Out:
# 1980     99137
# 1981    110563
# 1982    104271
# 1983     75550
# 1984     73417
# 1985     69978
# 1986     86048
# 1987    134771
# 1988    139306
# 1989    164432
# 1990    188054
# 1991    207509
# 1992    221687
# 1993    222049
# 1994    193665
# 1995    187712
# 1996    200085
# 1997    192885
# 1998    160727
# 1999    179818
# 2000    216712
# 2001    242643
# 2002    223111
# 2003    217297
# 2004    232083
# 2005    257457
# 2006    247057
# 2007    232405
# 2008    243047
# 2009    248768
# 2010    276956
# 2011    246194
# 2012    256222
# 2013    257537
# dtype: int64

# %%
canada['Total']=canada[years].sum(axis=1)
canada.head()
# Out:
#                       Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania         Immigrants  Foreigners   908   Europe   925  Southern Europe
# Algeria         Immigrants  Foreigners   903   Africa   912  Northern Africa
# American Samoa  Immigrants  Foreigners   909  Oceania   957        Polynesia
# Andorra         Immigrants  Foreigners   908   Europe   925  Southern Europe
#
#                 DEV             DevName  1980  1981  1982  1983  1984  1985  \
# OdName
# Afghanistan     902  Developing regions    16    39    39    47    71   340
# Albania         901   Developed regions     1     0     0     0     0     0
# Algeria         902  Developing regions    80    67    71    69    63    44
# American Samoa  902  Developing regions     0     1     0     0     0     0
# Andorra         901   Developed regions     0     0     0     0     0     0
#
# ...
